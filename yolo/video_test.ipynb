# %% [markdown]
# # Video

# %%
# Import Essential Libraries
import os
import cv2
from ultralytics import YOLO
from IPython.display import Video
from tqdm.notebook import trange, tqdm
import warnings

warnings.filterwarnings('ignore')

video_path = "C:/Users/NURŞAH SATILMIŞ/Desktop/AI_ARGE/yolo";

# %%
# Load a trained model
video_model = YOLO("C:/Users/NURŞAH SATILMIŞ/runs/detect/train7/weights/best.onnx")

# %% [markdown]
# ## Test with first video

# %%
# test video 1
first_path = os.path.join(video_path,"TrafficSignLocalizationandDetection/test_video1.mp4")
Video(first_path, width=800,embed=True)
# Out:
# <video controls  width="800" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
#valid size is 416x416 
#check size


# Open the video file
cap = cv2.VideoCapture(first_path)

# Get the width and height of the video frames
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

print(f"Video dimensions: {width}x{height}")

# Release the VideoCapture object
cap.release()
# Out:
# Video dimensions: 416x416

# %%
# Use the model to detect signs
video_model.predict(source=first_path, show=True, save = True)
# Out:
# Loading C:\Users\NURŞAH SATILMIŞ\runs\detect\train7\weights\best.onnx for ONNX Runtime inference...
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Use the model to detect signs
# ----> 2 video_model.predict(source=first_path, show=True, save = True)
#
# ...

# %%
"C:\Users\NURŞAH SATILMIŞ\Desktop\AI_ARGE\yolo\detect\train73"

# %%
# show result
# Convert format
# !ffmpeg -y -loglevel panic -i os.path.join(video_path,detect/predict/video.avi result_out1.mp4)
# Display the video 
Video("result_out.mp4", width=960)

# %% [markdown]
# ## Test With second video

# %%
# test video 1
Video(os.path.join(video_path,"TrafficSignLocalizationandDetection/test_video2.mp4"), width=800,embed=True)
# Out:
# <video controls  width="800" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
#valid size is 416x416 
#check size


# Open the video file
cap = cv2.VideoCapture(os.path.join(video_path,"TrafficSignLocalizationandDetection/test_video2.mp4"))

# Get the width and height of the video frames
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

print(f"Video dimensions: {width}x{height}")

# Release the VideoCapture object
cap.release()
# Out:
# Video dimensions: 1280x720

# %%
# resize videos ıf needed


# Open the video file
cap = cv2.VideoCapture(os.path.join(video_path,"TrafficSignLocalizationandDetection/test_video2.mp4"))

# Get the width and height of the video frames
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the new width and height for resizing
new_width = 416
new_height = 416


# Create a VideoWriter object to save the resized video
out = cv2.VideoWriter('TrafficSignLocalizationandDetection/resized_video2.mp4', cv2.VideoWriter_fourcc(*'mp4V'), 30, (new_width, new_height))

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    # Resize the frame
    resized_frame = cv2.resize(frame, (new_width, new_height))

    # Write the resized frame to the output video
    out.write(resized_frame)

    # Display the resized frame (optional)
    cv2.imshow('Resized Video', resized_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture and VideoWriter objects
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
 
# Use the model to detect signs
video_model.predict(source=os.path.join(video_path,"TrafficSignLocalizationandDetection/resized_video2.mp4"), show=True, save = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Use the model to detect signs
# ----> 2 video_model.predict(source=os.path.join(video_path,"TrafficSignLocalizationandDetection/resized_video2.mp4"), show=True, save = True)
#
# ...

# %%
# show result
# Convert format
# !ffmpeg -y -loglevel panic -i os.path.join(video_path,detect/predict/video.avi result_out1.mp4)

# Display the video 
Video("result_out.mp4", width=960)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 # show result
#       2 # Convert format
#       3
#       4 # Display the video
# ----> 5 Video("result_out.mp4", width=960)
#
# File c:\Users\NURŞAH SATILMIŞ\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:1162, in Video.__init__(self, data, url, filename, embed, mimetype, width, height, html_attributes)
#    1156 if data and not embed:
#    1157     msg = ''.join([
#    1158         "To embed videos, you must pass embed=True ",
#    1159         "(this may make your notebook files huge)\n",
#    1160         "Consider passing Video(url='...')",
#    1161     ])
# -> 1162     raise ValueError(msg)
#    1164 self.mimetype = mimetype
#    1165 self.embed = embed
#
# ValueError: To embed videos, you must pass embed=True (this may make your notebook files huge)
# ...
